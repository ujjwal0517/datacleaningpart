# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/rohit/DataSet/ml-latest-small/links.csv")
result = df.to_json('wow.json')
result

# %%
dataframe = pd.read_json('wow.json')
dataframe
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
first
# Out:
# array([114709, 113497, 113228, 114885, 113041, 113277, 114319, 112302,
#        114576, 113189, 112346, 112896, 112453, 113987, 112760, 112641,
#        114388, 113101, 112281, 113845, 113161, 112722, 112401, 114168,
#        113627, 114057, 114011, 114117, 112682, 115012, 112792, 114746,
#        112431, 112818, 113442, 112697, 112749, 114279, 112819, 114272,
#        113855, 114681, 113347, 114369, 114148, 114916, 114814, 113819,
#        110299, 112499, 113158, 113321, 110877, 113419, 116260, 113862,
#        116126, 118002, 115683, 116839, 113149, 113118, 116367, 113010,
#        113537, 113828, 115644, 115676, 114367, 113973, 112744, 116731,
#        112445, 114660, 112379, 114039, 112365, 118158, 116151, 115697,
#        113972, 117002, 114825, 115639, 115759, 113403, 113247, 113283,
#        115907, 115734, 117102, 118040, 116483, 112579, 110251, 117110,
#        112646, 112573,  75314, 113326, 115645, 112373, 115033, 116606,
# ...

# %%
import requests
data = []

# %%
first = df['imdbId'].iloc[0:5].values
for i in first:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=506805a0")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
data
# Out:
# [{'Title': 'Toy Story',
#   'Year': '1995',
#   'Rated': 'G',
#   'Released': '22 Nov 1995',
#   'Runtime': '81 min',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#   'Director': 'John Lasseter',
#   'Writer': 'John Lasseter (original story by), Pete Docter (original story by), Andrew Stanton (original story by), Joe Ranft (original story by), Joss Whedon (screenplay by), Andrew Stanton (screenplay by), Joel Cohen (screenplay by), Alec Sokolow (screenplay by)',
#   'Actors': 'Tom Hanks, Tim Allen, Don Rickles, Jim Varney',
#   'Plot': "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 3 Oscars. Another 27 wins & 20 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_SX300.jpg',
# ...

# %%
result = pd.DataFrame(data)
result
# Out:
#                          Title  Year  Rated     Released  Runtime  \
# 0                    Toy Story  1995      G  22 Nov 1995   81 min
# 1                      Jumanji  1995     PG  15 Dec 1995  104 min
# 2             Grumpier Old Men  1995  PG-13  22 Dec 1995  101 min
# 3            Waiting to Exhale  1995      R  22 Dec 1995  124 min
# 4  Father of the Bride Part II  1995     PG  08 Dec 1995  106 min
#
#                                            Genre         Director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               Writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# ...

# %%
result.to_json('wow1.json')

# %%
jsonfile = pd.read_json('wow1.json')
jsonfile.to_json()
# Out:
# '{"Title":{"0":"Toy Story","1":"Jumanji","2":"Grumpier Old Men","3":"Waiting to Exhale","4":"Father of the Bride Part II"},"Year":{"0":1995,"1":1995,"2":1995,"3":1995,"4":1995},"Rated":{"0":"G","1":"PG","2":"PG-13","3":"R","4":"PG"},"Released":{"0":"22 Nov 1995","1":"15 Dec 1995","2":"22 Dec 1995","3":"22 Dec 1995","4":"08 Dec 1995"},"Runtime":{"0":"81 min","1":"104 min","2":"101 min","3":"124 min","4":"106 min"},"Genre":{"0":"Animation, Adventure, Comedy, Family, Fantasy","1":"Adventure, Comedy, Family, Fantasy","2":"Comedy, Romance","3":"Comedy, Drama, Romance","4":"Comedy, Family, Romance"},"Director":{"0":"John Lasseter","1":"Joe Johnston","2":"Howard Deutch","3":"Forest Whitaker","4":"Charles Shyer"},"Writer":{"0":"John Lasseter (original story by), Pete Docter (original story by), Andrew Stanton (original story by), Joe Ranft (original story by), Joss Whedon (screenplay by), Andrew Stanton (screenplay by), Joel Cohen (screenplay by), Alec Sokolow (screenplay by)","1":"Jonathan 
# ...

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 500

# %%
second = df['imdbId'].iloc[500:1000].values
for i in second:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=41c5f026")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 1000

# %%
five = df['imdbId'].iloc[1000:1900].values
for i in five:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=e4c29baa")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 1900

# %%
six = df['imdbId'].iloc[1900:2800].values
for i in six:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=c5734764")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 2800

# %%
seven = df['imdbId'].iloc[2800:3700].values
for i in seven:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=63068f4c")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 3700

# %%
eight = df['imdbId'].iloc[3700:4600].values
for i in eight:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=8674f3dd")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 4600

# %%
ten = df['imdbId'].iloc[4600:5500].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=796d1025")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 5500

# %%
ten = df['imdbId'].iloc[5500:6400].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=d5d5fcf8")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 6400

# %%
ten = df['imdbId'].iloc[6400:7300].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=694489f1")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 7300

# %%
ten = df['imdbId'].iloc[7300:8200].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=52bf027a")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 8200

# %%
ten = df['imdbId'].iloc[8200:9100].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=4b8ef37")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 9100

# %%
ten = df['imdbId'].iloc[9100:].values
for i in ten:
    response = requests.get("http://www.omdbapi.com/?i=tt0"+str(i)+"&apikey=32d41f18")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
data
# Out:
# [{'Title': 'Toy Story',
#   'Year': '1995',
#   'Rated': 'G',
#   'Released': '22 Nov 1995',
#   'Runtime': '81 min',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#   'Director': 'John Lasseter',
#   'Writer': 'John Lasseter (original story by), Pete Docter (original story by), Andrew Stanton (original story by), Joe Ranft (original story by), Joss Whedon (screenplay by), Andrew Stanton (screenplay by), Joel Cohen (screenplay by), Alec Sokolow (screenplay by)',
#   'Actors': 'Tom Hanks, Tim Allen, Don Rickles, Jim Varney',
#   'Plot': "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 3 Oscars. Another 27 wins & 20 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_SX300.jpg',
# ...

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#                                    Title  Year  Rated     Released  Runtime  \
# 0                              Toy Story  1995      G  22 Nov 1995   81 min
# 1                                Jumanji  1995     PG  15 Dec 1995  104 min
# 2                       Grumpier Old Men  1995  PG-13  22 Dec 1995  101 min
# 3                      Waiting to Exhale  1995      R  22 Dec 1995  124 min
# 4            Father of the Bride Part II  1995     PG  08 Dec 1995  106 min
# ...                                  ...   ...    ...          ...      ...
# 9737  Black Butler: Book of the Atlantic  2017  TV-MA  12 Jun 2017  101 min
# 9738               No Game No Life: Zero  2017  TV-14  05 Oct 2017  110 min
# 9739                               Flint  2017  TV-14  28 Oct 2017   86 min
# 9740        Bungo Stray Dogs: Dead Apple  2018    N/A  02 May 2018   90 min
# 9741                          Dice Rules  1991  NC-17  17 May 1991   88 min
#
# ...

# %%
dataset['Response'].unique()
# Out:
# array(['True', 'False'], dtype=object)

# %%
dataset.to_csv("file1.csv")
