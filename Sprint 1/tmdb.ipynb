# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/rohit/DataSet/ml-latest-small/links.csv")
type(df['tmdbId'].values)
df.count()
# Out:
# movieId    9742
# imdbId     9742
# tmdbId     9734
# dtype: int64

# %%
x = pd.isna(df['tmdbId'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9737    False
# 9738    False
# 9739    False
# 9740    False
# 9741    False
# Name: tmdbId, Length: 9742, dtype: bool

# %%
df['x']=x
df=df[df['x']==False]
del df['x']
df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9734 rows x 3 columns]

# %%
first = df['tmdbId'].values
value=[]
for i in first:
    value.append(int(i))

value
# Out:
# [862,
#  8844,
#  15602,
#  31357,
#  11862,
#  949,
#  11860,
#  45325,
#  9091,
#  710,
#  9087,
#  12110,
#  21032,
#  10858,
#  1408,
#  524,
#  4584,
#  5,
#  9273,
#  11517,
#  8012,
#  1710,
#  9691,
#  12665,
#  451,
#  16420,
#  9263,
#  17015,
#  902,
#  37557,
#  9909,
#  63,
#  9598,
#  687,
#  33689,
#  9603,
#  34615,
#  31174,
#  11443,
#  35196,
#  9312,
#  577,
#  11861,
#  807,
#  10530,
#  8391,
#  629,
#  11448,
#  49133,
#  26441,
#  97406,
#  9089,
#  11010,
#  11359,
#  17182,
#  2054,
#  10607,
#  19760,
#  9536,
#  11525,
#  4482,
#  10634,
#  755,
#  11859,
#  28387,
#  48750,
#  20927,
#  36929,
#  9102,
#  124626,
#  27526,
#  9623,
#  46785,
#  400,
#  880,
#  146599,
#  8447,
#  10534,
#  17414,
#  13997,
#  2086,
#  9095,
#  12158,
#  9283,
#  9208,
#  40154,
#  406,
#  63076,
#  11062,
#  13685,
#  47475,
#  2045,
#  9614,
#  688,
#  11907,
#  10874,
#  89333,
#  197,
#  103,
#  33542,
#  43566,
#  51352,
#  16934,
#  10324,
#  78406,
#  32119,
# ...

# %%
import requests

# %%
data=[]

# %%
for i in value:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    data.append(response.json())

# %%
response.status_code
# Out:
# 200

# %%
len(data)
# Out:
# 955
