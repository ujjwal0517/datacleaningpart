# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/home/rohit/DataSet/metadata_wala/movies_metadata.csv",dtype={'overview':"string"})

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df_meta = pd.read_csv("/home/rohit/DataSet/metadata_wala/links.csv")

# %%
df_meta.tail()
# Out:
#        movieId   imdbId    tmdbId
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0

# %%
df_meta.sort_index()
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
type(df_meta['imdbId'])
# Out:
# pandas.core.series.Series

# %%
df_meta.count()
# Out:
# movieId    45843
# imdbId     45843
# tmdbId     45624
# dtype: int64

# %%
df_movielens = pd.read_csv("/home/rohit/DataSet/ml-25m/links.csv")

# %%
df_movielens.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movielens.sort_index()
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 62418   209157  6671244  499546.0
# 62419   209159   297986   63407.0
# 62420   209163  6755366  553036.0
# 62421   209169   249603  162892.0
# 62422   209171    55323   79513.0
#
# [62423 rows x 3 columns]

# %%
df_movielens.iloc[45838:]
# Out:
#        movieId   imdbId    tmdbId
# 45838   171219  1638277  177117.0
# 45839   171221  4287348  380754.0
# 45840   171223  3309038  229693.0
# 45841   171225  5736592  412766.0
# 45842   171227  4795124  425134.0
# ...        ...      ...       ...
# 62418   209157  6671244  499546.0
# 62419   209159   297986   63407.0
# 62420   209163  6755366  553036.0
# 62421   209169   249603  162892.0
# 62422   209171    55323   79513.0
#
# [16585 rows x 3 columns]

# %%
df_meta.tail()
# Out:
#        movieId   imdbId    tmdbId
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0

# %%
df_movielens.count()
# Out:
# movieId    62423
# imdbId     62423
# tmdbId     62316
# dtype: int64

# %%
df_movielens.sort_index()
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 62418   209157  6671244  499546.0
# 62419   209159   297986   63407.0
# 62420   209163  6755366  553036.0
# 62421   209169   249603  162892.0
# 62422   209171    55323   79513.0
#
# [62423 rows x 3 columns]

# %%
df_movielens.merge(df_meta,indicator=True,how='outer')
# Out:
#        movieId   imdbId    tmdbId      _merge
# 0            1   114709     862.0        both
# 1            2   113497    8844.0        both
# 2            3   113228   15602.0        both
# 3            4   114885   31357.0        both
# 4            5   113041   11862.0        both
# ...        ...      ...       ...         ...
# 65199   174947  6612512  462026.0  right_only
# 65200   175295  1129418  419786.0  right_only
# 65201   175567  4815426  369363.0  right_only
# 65202   175607   238304  353921.0  right_only
# 65203   175985  1883368  335251.0  right_only
#
# [65204 rows x 4 columns]

# %%
df_meta.count()
# Out:
# movieId    45843
# imdbId     45843
# tmdbId     45624
# dtype: int64

# %%
df_movielens.count()
# Out:
# movieId    62423
# imdbId     62423
# tmdbId     62316
# dtype: int64

# %%
df_meta.columns
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
df_meta['tmdbId']
# Out:
# 0           862.0
# 1          8844.0
# 2         15602.0
# 3         31357.0
# 4         11862.0
#            ...
# 45838    439050.0
# 45839    111109.0
# 45840     67758.0
# 45841    227506.0
# 45842    461257.0
# Name: tmdbId, Length: 45843, dtype: float64

# %%
df_meta = df_meta[df_meta['tmdbId'].notna()]

# %%
df_meta
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45624 rows x 3 columns]

# %%
df_meta[df_meta['tmdbId'].isna()]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId]
# Index: []

# %%
df_movielens.count()
# Out:
# movieId    62423
# imdbId     62423
# tmdbId     62316
# dtype: int64

# %%
df_movielens = df_movielens[df_movielens['tmdbId'].notna()]

# %%
df_movielens.count()
# Out:
# movieId    62316
# imdbId     62316
# tmdbId     62316
# dtype: int64

# %%
df_movielens[df_movielens['tmdbId'].isna()]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId]
# Index: []

# %%
df_merged = df_movielens.merge(df_meta,indicator=True,how='outer')

# %%
df_merged
# Out:
#        movieId   imdbId    tmdbId      _merge
# 0            1   114709     862.0        both
# 1            2   113497    8844.0        both
# 2            3   113228   15602.0        both
# 3            4   114885   31357.0        both
# 4            5   113041   11862.0        both
# ...        ...      ...       ...         ...
# 64975   174947  6612512  462026.0  right_only
# 64976   175295  1129418  419786.0  right_only
# 64977   175567  4815426  369363.0  right_only
# 64978   175607   238304  353921.0  right_only
# 64979   175985  1883368  335251.0  right_only
#
# [64980 rows x 4 columns]

# %%
df_meta[df_meta['imdbId']==6612512]
# Out:
#        movieId   imdbId    tmdbId
# 45351   174947  6612512  462026.0

# %%
df_for_api = df_merged[df_merged['_merge']!='both']

# %%
df_for_api
# Out:
#        movieId   imdbId    tmdbId      _merge
# 140        142    94878  525153.0   left_only
# 596        604   115978  538286.0   left_only
# 705        720   118114  503475.0   left_only
# 751        769   116992  581579.0   left_only
# 799        821   112746  525936.0   left_only
# ...        ...      ...       ...         ...
# 64975   174947  6612512  462026.0  right_only
# 64976   175295  1129418  419786.0  right_only
# 64977   175567  4815426  369363.0  right_only
# 64978   175607   238304  353921.0  right_only
# 64979   175985  1883368  335251.0  right_only
#
# [22020 rows x 4 columns]

# %%
df_for_api.count()
# Out:
# movieId    22020
# imdbId     22020
# tmdbId     22020
# _merge     22020
# dtype: int64

# %%
df_for_api.head()
# Out:
#      movieId  imdbId    tmdbId     _merge
# 140      142   94878  525153.0  left_only
# 596      604  115978  538286.0  left_only
# 705      720  118114  503475.0  left_only
# 751      769  116992  581579.0  left_only
# 799      821  112746  525936.0  left_only

# %%
df_for_api.to_csv("for_api_serach.csv")

# %%
df_for_api.sort_index()
# Out:
#        movieId   imdbId    tmdbId      _merge
# 140        142    94878  525153.0   left_only
# 596        604   115978  538286.0   left_only
# 705        720   118114  503475.0   left_only
# 751        769   116992  581579.0   left_only
# 799        821   112746  525936.0   left_only
# ...        ...      ...       ...         ...
# 64975   174947  6612512  462026.0  right_only
# 64976   175295  1129418  419786.0  right_only
# 64977   175567  4815426  369363.0  right_only
# 64978   175607   238304  353921.0  right_only
# 64979   175985  1883368  335251.0  right_only
#
# [22020 rows x 4 columns]

# %%
import json
a = [1,2,3]
with open('test.txt', 'w') as f:
    f.write(json.dumps(a))

#Now read the file back into a Python list object
with open('test.txt', 'r') as f:
    a = json.loads(f.read())
a
# Out:
# [1, 2, 3]

# %%
tmdbvalues = df_for_api['tmdbId'].values
tmdbvalues
# Out:
# array([525153., 538286., 503475., ..., 369363., 353921., 335251.])

# %%
valuesInInt = []
for i in tmdbvalues:
    valuesInInt.append(int(i))
valuesInInt
# Out:
# [525153,
#  538286,
#  503475,
#  581579,
#  525936,
#  484245,
#  470646,
#  575751,
#  566972,
#  572997,
#  559489,
#  531591,
#  558884,
#  581335,
#  207490,
#  579140,
#  131894,
#  83864,
#  205061,
#  40177,
#  575026,
#  54623,
#  90984,
#  15976,
#  119290,
#  84481,
#  130050,
#  493059,
#  602262,
#  93018,
#  215794,
#  148584,
#  44061,
#  20093,
#  94721,
#  50663,
#  541083,
#  526268,
#  92131,
#  88934,
#  119881,
#  94840,
#  61835,
#  65043,
#  510030,
#  104831,
#  302869,
#  150100,
#  54416,
#  116581,
#  507149,
#  59712,
#  164453,
#  44742,
#  277452,
#  112023,
#  271770,
#  37674,
#  593548,
#  80087,
#  42042,
#  79866,
#  193614,
#  8343,
#  186932,
#  123212,
#  421763,
#  45319,
#  70834,
#  97332,
#  85828,
#  27288,
#  73062,
#  525641,
#  479201,
#  269077,
#  50528,
#  149874,
#  103204,
#  176146,
#  153168,
#  470358,
#  109578,
#  98301,
#  595378,
#  76353,
#  574379,
#  100556,
#  486599,
#  54864,
#  580560,
#  112408,
#  503936,
#  593020,
# ...

# %%
type(valuesInInt)
# Out:
# list

# %%
import requests

# %%
import json
with open('tmdbid_list.txt','w') as f:
    f.write(json.dumps(valuesInInt))
with open('tmdbid_list.txt', 'r') as f:
    a = json.loads(f.read())
a
# Out:
# [525153,
#  538286,
#  503475,
#  581579,
#  525936,
#  484245,
#  470646,
#  575751,
#  566972,
#  572997,
#  559489,
#  531591,
#  558884,
#  581335,
#  207490,
#  579140,
#  131894,
#  83864,
#  205061,
#  40177,
#  575026,
#  54623,
#  90984,
#  15976,
#  119290,
#  84481,
#  130050,
#  493059,
#  602262,
#  93018,
#  215794,
#  148584,
#  44061,
#  20093,
#  94721,
#  50663,
#  541083,
#  526268,
#  92131,
#  88934,
#  119881,
#  94840,
#  61835,
#  65043,
#  510030,
#  104831,
#  302869,
#  150100,
#  54416,
#  116581,
#  507149,
#  59712,
#  164453,
#  44742,
#  277452,
#  112023,
#  271770,
#  37674,
#  593548,
#  80087,
#  42042,
#  79866,
#  193614,
#  8343,
#  186932,
#  123212,
#  421763,
#  45319,
#  70834,
#  97332,
#  85828,
#  27288,
#  73062,
#  525641,
#  479201,
#  269077,
#  50528,
#  149874,
#  103204,
#  176146,
#  153168,
#  470358,
#  109578,
#  98301,
#  595378,
#  76353,
#  574379,
#  100556,
#  486599,
#  54864,
#  580560,
#  112408,
#  503936,
#  593020,
# ...

# %%
first = df_for_api['tmdbId'].iloc[0:2]
data = []
for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())

# %%
len(data)
# Out:
# 1

# %%
with open('so_far.txt','w') as f:
    f.write(json.dumps(data))

# %%
first = df_for_api['tmdbId'].iloc[2:8]

for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())

# %%
with open('so_far.txt','w') as f:
    f.write(json.dumps(data))

# %%
len(data)
# Out:
# 7

# %%
with open('so_far.txt','r') as f:
    data = json.loads(f.read())
len(data)
# Out:
# 7

# %%
first = df_for_api['tmdbId'].iloc[8:10]

for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())

# %%
with open('so_far.txt','w') as f:
    f.write(json.dumps(data))

# %%
len(data)
# Out:
# 9

# %%
import time

# %%
len(data)
# Out:
# 9

# %%
first = df_for_api['tmdbId'].iloc[10:1500]

for i in first:
    time.sleep(5)
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    
    if(response.status_code==200):
        data.append(response.json())

# %%
with open('so_far.txt','w') as f:
    f.write(json.dumps(data))

# %%
len(data)

# %%
first = df_for_api['tmdbId'].iloc[6000:7500]

for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())

# %%
len(data)

# %%
first = df_for_api['tmdbId'].iloc[7500:9000]

for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())

# %%
len(data)

# %%
first = df_for_api['tmdbId'].iloc[9000:10000]

for i in first:
    response = requests.get("https://api.themoviedb.org/3/movie/"+str(i)+"?api_key=ea575fa4bf65c424e93e0c032ab5c5f2")
    if(response.status_code==200):
        data.append(response.json())
